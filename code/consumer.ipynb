# %%
import requests

url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=IBM&apikey=demo'
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes', '2. Symbol': 'IBM', '3. Last Refreshed': '2025-10-29', '4. Output Size': 'Compact', '5. Time Zone': 'US/Eastern'}, 'Time Series (Daily)': {'2025-10-29': {'1. open': '312.7900', '2. high': '314.3300', '3. low': '307.5200', '4. close': '308.2100', '5. volume': '4135948'}, '2025-10-28': {'1. open': '312.6000', '2. high': '319.3500', '3. low': '311.4100', '4. close': '312.5700', '5. volume': '6044770'}, '2025-10-27': {'1. open': '307.8000', '2. high': '313.5000', '3. low': '302.8800', '4. close': '313.0900', '5. volume': '9868151'}, '2025-10-24': {'1. open': '283.7700', '2. high': '310.7500', '3. low': '282.2100', '4. close': '307.4600', '5. volume': '16914243'}, '2025-10-23': {'1. open': '264.9500', '2. high': '285.5791', '3. low': '263.5623', '4. close': '285.0000', '5. volume': '16676394'}, '2025-10-22': {'1. open': '281.9900', '2. high': '289.1700', '3. low': '281.3500', '4. close': '287.5100', '5. volume': '10538480'}, '2025-10-21': {'1. open': '283.3100', '2. high': '285.3100', '3. low': '281.6000', '4. close': '282.0500', '5. volume': '4080981'}, '2025-10-20': {'1. open': '281.2500', '2. high': '285.5000', '3. low': '280.9600', '4. close': '283.6500', '5. volume': '3494336'}, '2025-10-17': {'1. open': '276.1500', '2. high': '283.4000', '3. low': '275.3500', '4. close': '281.2800', '5. volume': '5309565'}, '2025-10-16': {'1. open': '281.1100', '2. high': '282.5600', '3. low': '275.6000', '4. close': '275.9700', '5. volume': '2956923'}, '2025-10-15': {'1. open': '278.3800', '2. high': '285.4500', '3. low': '277.0000', '4. close': '280.7500', '5. volume': '3346753'}, '2025-10-14': {'1. open': '275.5200', '2. high': '277.5300', '3. low': '272.5469', '4. close': '276.1500', '5. volume': '3058149'}, '2025-10-13': {'1. open': '279.7900', '2. high': '282.4399', '3. low': '274.6400', '4. close': '277.2200', '5. volume': '4333836'}, '2025-10-10': {'1. open': '288.9700', '2. high': '290.3850', '3. low': '277.5000', '4. close': '277.8200', '5. volume': '4508506'}, '2025-10-09': {'1. open': '289.8200', '2. high': '290.1300', '3. low': '283.3200', '4. close': '288.2300', '5. volume': '4912375'}, '2025-10-08': {'1. open': '294.1600', '2. high': '294.2000', '3. low': '286.4730', '4. close': '289.4600', '5. volume': '5297030'}, '2025-10-07': {'1. open': '295.5500', '2. high': '301.0425', '3. low': '293.2850', '4. close': '293.8700', '5. volume': '7190126'}, '2025-10-06': {'1. open': '288.6100', '2. high': '291.4500', '3. low': '287.8000', '4. close': '289.4200', '5. volume': '2881947'}, '2025-10-03': {'1. open': '287.5000', '2. high': '293.3200', '3. low': '287.3000', '4. close': '288.3700', '5. volume': '4375082'}, '2025-10-02': {'1. open': '285.7900', '2. high': '288.5400', '3. low': '282.7900', '4. close': '286.7200', '5. volume': '3814232'}, '2025-10-01': {'1. open': '280.2000', '2. high': '286.5900', '3. low': '280.1500', '4. close': '286.4900', '5. volume': '4381338'}, '2025-09-30': {'1. open': '280.8800', '2. high': '286.0250', '3. low': '280.5200', '4. close': '282.1600', '5. volume': '5926924'}, '2025-09-29': {'1. open': '286.0000', '2. high': '286.0000', '3. low': '279.6600', '4. close': '279.8000', '5. volume': '6022125'}, '2025-09-26': {'1. open': '280.5100', '2. high': '288.8500', '3. low': '280.1100', '4. close': '284.3100', '5. volume': '9063938'}, '2025-09-25': {'1. open': '272.9350', '2. high': '284.2300', '3. low': '271.1480', '4. close': '281.4400', '5. volume': '11506192'}, '2025-09-24': {'1. open': '272.6200', '2. high': '273.6499', '3. low': '267.3000', '4. close': '267.5300', '5. volume': '3159924'}, '2025-09-23': {'1. open': '272.7000', '2. high': '273.2962', '3. low': '269.2650', '4. close': '272.2400', '5. volume': '5394121'}, '2025-09-22': {'1. open': '266.6200', '2. high': '272.3100', '3. low': '266.0000', '4. close': '271.3700', '5. volume': '5030540'}, '2025-09-19': {'1. open': '266.0500', '2. high': '267.8700', '3. low': '263 ...

# %%
import json
import boto3
import pandas as pd
from io import StringIO
from kafka import KafkaConsumer
from datetime import datetime

# ========== CONFIG ==========
KAFKA_BROKER = '*'       # IP:port Kafka broker
TOPIC_NAME = 'stockdata_demo'              #  topic  
AWS_ACCESS_KEY = '*'
AWS_SECRET_KEY = '*'
S3_BUCKET = 'reddit-scrapped-data0922-5123-0539'     # Tên bucket S3 
S3_FOLDER = 'data/'             # Thư mục con trong S3 
REGION = 'ap-southeast-2'             # Region AWS


def upload_csv_to_s3(data, filename):
    """
    Upload 1 bản ghi JSON lên S3 dưới dạng CSV (append nếu file đã có)
    """
    # --- Convert JSON sang DataFrame ---
    df = pd.DataFrame([data])

    # --- Convert sang CSV string ---
    csv_buffer = StringIO()
    df.to_csv(csv_buffer, index=False)

    # --- Kết nối S3 ---
    s3 = boto3.client(
        's3',
        aws_access_key_id=AWS_ACCESS_KEY,
        aws_secret_access_key=AWS_SECRET_KEY,
        region_name=REGION
    )

    key = f"{S3_FOLDER}{filename}"

    # --- Kiểm tra nếu file đã tồn tại để append ---
    try:
        existing_obj = s3.get_object(Bucket=S3_BUCKET, Key=key)
        existing_csv = existing_obj['Body'].read().decode('utf-8')

        # Nối dữ liệu mới vào CSV cũ
        existing_df = pd.read_csv(StringIO(existing_csv))
        combined_df = pd.concat([existing_df, df], ignore_index=True)

        csv_buffer = StringIO()
        combined_df.to_csv(csv_buffer, index=False)
        print(f"[APPEND] Added new row to {key}")
    except s3.exceptions.NoSuchKey:
        print(f"[CREATE] Creating new file {key}")

    # --- Upload lại lên S3 ---
    s3.put_object(Bucket=S3_BUCKET, Key=key, Body=csv_buffer.getvalue())
    print(f"[UPLOAD] Uploaded CSV to {key}")


def consume_and_upload():
    """
    Consumer Kafka: đọc dữ liệu JSON và upload CSV lên S3
    """
    consumer = KafkaConsumer(
        TOPIC_NAME,
        bootstrap_servers=[KAFKA_BROKER],
        value_deserializer=lambda x: json.loads(x.decode('utf-8')),
    )

    print(f"[INFO] Connected to Kafka broker: {KAFKA_BROKER}")
    print(f"[INFO] Listening to topic: {TOPIC_NAME}")

    for message in consumer:
        data = message.value

        # Nếu JSON có key 'ticker' hoặc 'symbol'
        symbol = data.get('ticker') or data.get('symbol') or 'UNKNOWN'
        filename = f"all_stocks.csv"

        print(f"[RECEIVED] {symbol} - Price: {data.get('price')}")

        upload_csv_to_s3(data, filename)


if __name__ == "__main__":
    consume_and_upload()
# Out:
# [INFO] Connected to Kafka broker: 3.27.142.86:9092
# [INFO] Listening to topic: stockdata_demo
# [RECEIVED] NVDA - Price: 202.39
# [CREATE] Creating new file data/all_stocks.csv
# [UPLOAD] Uploaded CSV to data/all_stocks.csv
# [RECEIVED] AMD - Price: 256.06
# [APPEND] Added new row to data/all_stocks.csv
# [UPLOAD] Uploaded CSV to data/all_stocks.csv
# [RECEIVED] INTC - Price: 39.98
# [APPEND] Added new row to data/all_stocks.csv
# [UPLOAD] Uploaded CSV to data/all_stocks.csv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 86
#      82         upload_csv_to_s3(data, filename)
#      85 if __name__ == "__main__":
# ---> 86     consume_and_upload()
#
# Cell In[6], line 73, in consume_and_upload()
#      70 print(f"[INFO] Connected to Kafka broker: {KAFKA_BROKER}")
#      71 print(f"[INFO] Listening to topic: {TOPIC_NAME}")
# ---> 73 for message in consumer:
#      74     data = message.value
#      76     # Nếu JSON có key 'ticker' hoặc 'symbol'
#
# File ~/.conda/envs/stock_data/lib/python3.9/site-packages/kafka/consumer/group.py:1188, in KafkaConsumer.__next__(self)
#    1186     self._iterator = self._message_generator_v2()
#    1187 try:
# -> 1188     return next(self._iterator)
#    1189 except StopIteration:
#    1190     self._iterator = None
#
# File ~/.conda/envs/stock_data/lib/python3.9/site-packages/kafka/consumer/group.py:1160, in KafkaConsumer._message_generator_v2(self)
#    1158 def _message_generator_v2(self):
#    1159     timeout_ms = 1000 * max(0, self._consumer_timeout - time.time())
# -> 1160     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1161     for tp, records in six.iteritems(record_map):
#    1162         # Generators are stateful, and it is possible that the tp / records
#    1163         # here may become stale during iteration -- i.e., we seek to a
#    1164         # different offset, pause consumption, or lose assignment.
#    1165         for record in records:
#    1166             # is_fetchable(tp) should handle assignment changes and offset
#    1167             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1168             # outer function destroying the existing iterator/generator
#    1169             # via self._iterator = None
#
# File ~/.conda/envs/stock_data/lib/python3.9/site-packages/kafka/consumer/group.py:684, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     682 timer = Timer(timeout_ms)
#     683 while not self._closed:
# --> 684     records = self._poll_once(timer, max_records, update_offsets=update_offsets)
#     685     if records:
#     686         return records
#
# File ~/.conda/envs/stock_data/lib/python3.9/site-packages/kafka/consumer/group.py:731, in KafkaConsumer._poll_once(self, timer, max_records, update_offsets)
#     728     log.debug('poll: do not have all fetch positions...')
#     729     poll_timeout_ms = min(poll_timeout_ms, self.config['retry_backoff_ms'])
# --> 731 self._client.poll(timeout_ms=poll_timeout_ms)
#     732 # after the long poll, we should check whether the group needs to rebalance
#     733 # prior to returning data so that the group can stabilize faster
#     734 if self._coordinator.need_rejoin():
#
# File ~/.conda/envs/stock_data/lib/python3.9/site-packages/kafka/client_async.py:685, in KafkaClient.poll(self, timeout_ms, future)
#     678         timeout = min(
#     679             user_timeout_ms,
#     680             metadata_timeout_ms,
#     681             idle_connection_timeout_ms,
#     682             request_timeout_ms)
#     683         timeout = max(0, timeout)  # avoid negative timeouts
# --> 685     self._poll(timeout / 1000)
#     687 # called without the lock to avoid deadlock potential
#     688 # if handlers need to acquire locks
#     689 responses.extend(self._fire_pending_completed_requests())
#
# File ~/.conda/envs/stock_data/lib/python3.9/site-packages/kafka/client_async.py:728, in KafkaClient._poll(self, timeout)
#     725 self._register_send_sockets()
#     727 start_select = time.time()
# --> 728 ready = self._selector.select(timeout)
#     729 end_select = time.time()
#     730 if self._sensors:
#
# File ~/.conda/envs/stock_data/lib/python3.9/selectors.py:469, in EpollSelector.select(self, timeout)
#     467 ready = []
#     468 try:
# --> 469     fd_event_list = self._selector.poll(timeout, max_ev)
#     470 except InterruptedError:
#     471     return ready
#
# KeyboardInterrupt:
